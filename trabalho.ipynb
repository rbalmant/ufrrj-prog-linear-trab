# %% [markdown]
# # Introdução

# %%
import pandas as pd
import numpy as np

# %%
file = 'gladiator_data.csv'
df = pd.read_csv(file)
df
# Out:
#                         Name  Age  Birth Year    Origin  Height  Weight  \
# 0          Cosconius Hostius   42           8      Gaul     176      54
# 1         Caecilius Valerius   30          20    Greece     173      67
# 2           Sempronius Aulus   30          20      Gaul     171      81
# 3          Lacerius Laberius   32          18      Rome     172      72
# 4             Blaesus Modius   29          21      Gaul     177      87
# ...                      ...  ...         ...       ...     ...     ...
# 737565     Orestius Maecenas   45         354  Germania     167      92
# 737566    Sempronius Fannius   40         359      Rome     176      76
# 737567     Laberius Gracchus   28         371  Germania     176     108
# 737568   Matinius Percennius   32         367      Rome     186      79
# 737569  Coruncanius Numicius   20         379      Gaul     179     100
#
#            Category  Wins  Losses Special Skills  ... Battle Experience  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 737570 entries, 0 to 737569
# Data columns (total 29 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   Name                     737570 non-null  object
#  1   Age                      737570 non-null  int64
#  2   Birth Year               737570 non-null  int64
#  3   Origin                   737570 non-null  object
#  4   Height                   737570 non-null  int64
#  5   Weight                   737570 non-null  int64
#  6   Category                 737570 non-null  object
#  7   Wins                     737570 non-null  int64
#  8   Losses                   737570 non-null  int64
#  9   Special Skills           737570 non-null  object
#  10  Weapon of Choice         737570 non-null  object
#  11  Patron Wealth            737570 non-null  object
#  12  Equipment Quality        737570 non-null  object
# ...

# %%
df.columns
# Out:
# Index(['Name', 'Age', 'Birth Year', 'Origin', 'Height', 'Weight', 'Category',
#        'Wins', 'Losses', 'Special Skills', 'Weapon of Choice', 'Patron Wealth',
#        'Equipment Quality', 'Public Favor', 'Injury History',
#        'Mental Resilience', 'Diet and Nutrition', 'Tactical Knowledge',
#        'Allegiance Network', 'Battle Experience', 'Psychological Profile',
#        'Health Status', 'Personal Motivation', 'Previous Occupation',
#        'Training Intensity', 'Battle Strategy', 'Social Standing',
#        'Crowd Appeal Techniques', 'Survived'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Name                        object
# Age                          int64
# Birth Year                   int64
# Origin                      object
# Height                       int64
# Weight                       int64
# Category                    object
# Wins                         int64
# Losses                       int64
# Special Skills              object
# Weapon of Choice            object
# Patron Wealth               object
# Equipment Quality           object
# Public Favor               float64
# Injury History              object
# Mental Resilience          float64
# Diet and Nutrition          object
# Tactical Knowledge          object
# Allegiance Network          object
# Battle Experience            int64
# Psychological Profile       object
# Health Status               object
# Personal Motivation         object
# Previous Occupation         object
# Training Intensity          object
# Battle Strategy             object
# Social Standing             object
# ...

# %%
df.head()
# Out:
#                  Name  Age  Birth Year  Origin  Height  Weight     Category  \
# 0   Cosconius Hostius   42           8    Gaul     176      54  Hoplomachus
# 1  Caecilius Valerius   30          20  Greece     173      67   Provocator
# 2    Sempronius Aulus   30          20    Gaul     171      81  Hoplomachus
# 3   Lacerius Laberius   32          18    Rome     172      72    Retiarius
# 4      Blaesus Modius   29          21    Gaul     177      87      Secutor
#
#    Wins  Losses Special Skills  ... Battle Experience Psychological Profile  \
# 0    10       2         Novice  ...                12                 Stoic
# 1     6       0        Agility  ...                 6            Aggressive
# 2     8       4      Endurance  ...                12           Calculative
# 3     8       3         Novice  ...                11                 Stoic
# 4    12       5        Tactics  ...                17                 Stoic
#
# ...

# %%
df.shape
# Out:
# (737570, 29)

# %%
df.describe()
# Out:
#                  Age     Birth Year         Height         Weight  \
# count  737570.000000  737570.000000  737570.000000  737570.000000
# mean       31.508300     217.003697     175.335926      82.005254
# std         8.077172      98.571108      10.179014      16.032841
# min        18.000000       5.000000     127.000000       8.000000
# 25%        25.000000     137.000000     168.000000      71.000000
# 50%        32.000000     227.000000     175.000000      82.000000
# 75%        39.000000     303.000000     182.000000      93.000000
# max        45.000000     381.000000     226.000000     158.000000
#
#                 Wins         Losses   Public Favor  Mental Resilience  \
# count  737570.000000  737570.000000  737570.000000      737570.000000
# mean        7.879296       1.755328       0.697088           4.539400
# std         3.458866       1.704495       0.137605           2.328009
# min         0.000000       0.000000       0.240123           0.787137
# ...

# %%
df.describe(include='object')
# Out:
#                Name  Origin     Category Special Skills Weapon of Choice  \
# count        737570  737570       737570         737570           737570
# unique        32761       6            6              6                6
# top     Gaius Gaius    Rome  Hoplomachus         Novice           Dagger
# freq             94  123199       123399         463280           307292
#
#        Patron Wealth Equipment Quality Injury History Diet and Nutrition  \
# count         737570            737570         737570             737570
# unique             3                 3              2                  3
# top           Medium          Standard            Low           Adequate
# freq          246536            246536         585395             246536
#
#        Tactical Knowledge Allegiance Network Psychological Profile  \
# count              737570             737570                737570
# unique                  4                  3                     4
# ...

# %%
df_survived = df[df['Survived'] == True]
df_Notsurvived = df[df['Survived'] == False]

# %% [markdown]
# # Metodologia

# %% [markdown]
# # Resultados

# %% [markdown]
# # Conclusão
